# %% [markdown]
# # **Homework 12 - Reinforcement Learning**
#
# 若有任何問題，歡迎來信至助教信箱 ntu-ml-2021spring-ta@googlegroups.com

# %% [markdown]
# ## 前置作業
#
# 首先我們需要安裝必要的系統套件及 PyPi 套件。
# gym 這個套件由 OpenAI 所提供，是一套用來開發與比較 Reinforcement Learning 演算法的工具包（toolkit）。
# 而其餘套件則是為了在 Notebook 中繪圖所需要的套件。

# %%
# !nvidia-smi
# Out:
# Sun Jul 17 03:08:01 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !apt update
# !apt install python-opengl xvfb -y
# !pip install gym[box2d]==0.18.3 pyvirtualdisplay tqdm numpy==1.19.5 torch==1.8.1
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,302 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,329 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,057 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,897 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,526 kB]
# Fetched 11.4 MB in 3s (3,365 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 63 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl xvfb
# 0 upgraded, 2 newly installed, 0 to remove and 63 not upgraded.
# Need to get 1,281 kB of archives.
# After this operation, 7,687 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.11 [785 kB]
# Fetched 1,281 kB in 1s (1,990 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 155653 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.11_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.11) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.11) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gym[box2d]==0.18.3
#   Downloading gym-0.18.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.4 MB/s
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.0)
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 46.5 MB/s
# Collecting torch==1.8.1
#   Downloading torch-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (804.1 MB)
#      |████████████████████████████████| 804.1 MB 2.7 kB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1) (4.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.18.3) (1.7.3)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.18.3) (1.5.0)
# Requirement already satisfied: Pillow<=8.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.18.3) (7.1.2)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.18.3) (1.3.0)
# Collecting box2d-py~=2.3.5
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 74.5 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.15,>=1.4.0->gym[box2d]==0.18.3) (0.16.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.18.3-py3-none-any.whl size=1657533 sha256=a2caa0192f1897129716d36ce71bc018b1dbf7c90203c51c27fe56cd1b099ee8
#   Stored in directory: /root/.cache/pip/wheels/1a/ec/6d/705d53925f481ab70fd48ec7728558745eeae14dfda3b49c99
# Successfully built gym
# Installing collected packages: numpy, gym, box2d-py, torch, pyvirtualdisplay
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: gym
#     Found existing installation: gym 0.17.3
#     Uninstalling gym-0.17.3:
#       Successfully uninstalled gym-0.17.3
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.0+cu113
#     Uninstalling torch-1.12.0+cu113:
#       Successfully uninstalled torch-1.12.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# torchvision 0.13.0+cu113 requires torch==1.12.0, but you have torch 1.8.1 which is incompatible.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.8.1 which is incompatible.
# torchaudio 0.12.0+cu113 requires torch==1.12.0, but you have torch 1.8.1 which is incompatible.
# tensorflow 2.8.2+zzzcolab20220527125636 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed box2d-py-2.3.8 gym-0.18.3 numpy-1.19.5 pyvirtualdisplay-3.0 torch-1.8.1

# %% [markdown]
# 接下來，設置好 virtual display，並引入所有必要的套件。

# %%
# %%capture
from pyvirtualdisplay import Display
virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %matplotlib inline
import matplotlib.pyplot as plt

from IPython import display

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
from tqdm.notebook import tqdm

# %% [markdown]
# # 請不要更改 random seed !!!!
# # 不然在judgeboi上 你的成績不會被reproduce !!!!

# %%
seed = 543 # Do not change this
def fix(env, seed):
  env.seed(seed)
  env.action_space.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  np.random.seed(seed)
  random.seed(seed)
  torch.set_deterministic(True)
  torch.backends.cudnn.benchmark = False
  torch.backends.cudnn.deterministic = True

# %% [markdown]
# 最後，引入 OpenAI 的 gym，並建立一個 [Lunar Lander](https://gym.openai.com/envs/LunarLander-v2/) 環境。

# %%
# %%capture
import gym
import random
import numpy as np

env = gym.make('LunarLander-v2')

fix(env, seed)

# %%
import time
start = time.time()

# %%
# !pip freeze
# Out:
# absl-py==1.1.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.2.0
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arviz==0.12.1
# astor==0.8.1
# astropy==4.3.1
# astunparse==1.6.3
# atari-py==0.2.9
# atomicwrites==1.4.1
# attrs==21.4.0
# audioread==2.1.9
# autograd==1.4
# Babel==2.10.3
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==5.0.1
# blis==0.7.8
# bokeh==2.3.3
# box2d-py==2.3.8
# branca==0.5.0
# bs4==0.0.1
# CacheControl==0.12.11
# cached-property==1.5.2
# cachetools==4.2.4
# catalogue==2.0.7
# certifi==2022.6.15
# cffi==1.15.1
# cftime==1.6.1
# chardet==3.0.4
# charset-normalizer==2.1.0
# click==7.1.2
# cloudpickle==1.3.0
# cmake==3.22.5
# cmdstanpy==0.9.5
# colorcet==3.0.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.4.0
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cupy-cuda111==9.4.0
# cvxopt==1.2.7
# cvxpy==1.0.31
# cycler==0.11.0
# cymem==2.0.6
# Cython==0.29.30
# daft==0.0.4
# dask==2.12.0
# datascience==0.10.6
# debugpy==1.0.0
# decorator==4.4.2
# defusedxml==0.7.1
# deprecat==2.1.1
# descartes==1.1.0
# dill==0.3.5.1
# distributed==1.25.3
# dlib==19.18.0+zzzcolab20220513001918
# dm-tree==0.1.7
# docopt==0.6.2
# docutils==0.17.1
# dopamine-rl==1.0.5
# earthengine-api==0.1.316
# easydict==1.9
# ecos==2.0.10
# editdistance==0.5.3
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl
# entrypoints==0.4
# ephem==4.1.3
# et-xmlfile==1.1.0
# etils==0.6.0
# fa2==0.3.5
# fastai==2.7.6
# fastcore==1.4.5
# fastdownload==0.0.7
# fastdtw==0.3.4
# fastjsonschema==2.15.3
# fastprogress==1.0.2
# fastrlock==0.8
# fbprophet==0.7.1
# feather-format==0.4.1
# filelock==3.7.1
# firebase-admin==4.4.0
# fix-yahoo-finance==0.0.22
# Flask==1.1.4
# flatbuffers==2.0
# folium==0.8.3
# future==0.16.0
# gast==0.5.3
# GDAL==2.2.2
# gdown==4.4.0
# gensim==3.6.0
# geographiclib==1.52
# geopy==1.17.0
# gin-config==0.5.0
# glob2==0.7
# google==2.0.3
# google-api-core==1.31.6
# google-api-python-client==1.12.11
# google-auth==1.35.0
# google-auth-httplib2==0.0.4
# google-auth-oauthlib==0.4.6
# google-cloud-bigquery==1.21.0
# google-cloud-bigquery-storage==1.1.2
# google-cloud-core==1.0.3
# google-cloud-datastore==1.8.0
# google-cloud-firestore==1.7.0
# google-cloud-language==1.2.0
# google-cloud-storage==1.18.1
# google-cloud-translate==1.5.0
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz
# google-pasta==0.2.0
# google-resumable-media==0.4.1
# googleapis-common-protos==1.56.3
# googledrivedownloader==0.4
# graphviz==0.10.1
# greenlet==1.1.2
# grpcio==1.47.0
# gspread==3.4.2
# gspread-dataframe==3.0.8
# gym==0.18.3
# h5py==3.1.0
# HeapDict==1.0.1
# hijri-converter==2.2.4
# holidays==0.10.5.2
# holoviews==1.14.9
# html5lib==1.0.1
# httpimport==0.5.18
# httplib2==0.17.4
# httplib2shim==0.0.3
# humanize==0.5.1
# hyperopt==0.1.2
# ideep4py==2.0.0.post3
# idna==2.10
# imageio==2.4.1
# imagesize==1.4.1
# imbalanced-learn==0.8.1
# imblearn==0.0
# imgaug==0.2.9
# importlib-metadata==4.12.0
# importlib-resources==5.8.0
# imutils==0.5.4
# inflect==2.1.0
# iniconfig==1.1.1
# intel-openmp==2022.1.0
# intervaltree==2.1.0
# ipykernel==4.10.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# ipywidgets==7.7.1
# itsdangerous==1.1.0
# jax==0.3.14
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.3.14+cuda11.cudnn805-cp37-none-manylinux2014_x86_64.whl
# jedi==0.18.1
# jieba==0.42.1
# Jinja2==2.11.3
# joblib==1.1.0
# jpeg4py==0.1.4
# jsonschema==4.3.3
# jupyter==1.0.0
# jupyter-client==5.3.5
# jupyter-console==5.2.0
# jupyter-core==4.11.1
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==1.1.1
# kaggle==1.5.12
# kapre==0.3.7
# keras==2.8.0
# Keras-Preprocessing==1.1.2
# keras-vis==0.4.1
# kiwisolver==1.4.3
# korean-lunar-calendar==0.2.1
# langcodes==3.3.0
# libclang==14.0.1
# librosa==0.8.1
# lightgbm==2.2.3
# llvmlite==0.34.0
# lmdb==0.99
# LunarCalendar==0.0.9
# lxml==4.2.6
# Markdown==3.3.7
# MarkupSafe==2.0.1
# matplotlib==3.2.2
# matplotlib-inline==0.1.3
# matplotlib-venn==0.11.7
# missingno==0.5.1
# mistune==0.8.4
# mizani==0.6.0
# mkl==2019.0
# mlxtend==0.14.0
# more-itertools==8.13.0
# moviepy==0.2.3.5
# mpmath==1.2.1
# msgpack==1.0.4
# multiprocess==0.70.13
# multitasking==0.0.11
# murmurhash==1.0.7
# music21==5.5.0
# natsort==5.5.0
# nbclient==0.6.6
# nbconvert==5.6.1
# nbformat==5.4.0
# nest-asyncio==1.5.5
# netCDF4==1.6.0
# networkx==2.6.3
# nibabel==3.0.2
# nltk==3.7
# notebook==5.3.1
# numba==0.51.2
# numexpr==2.8.3
# numpy==1.19.5
# oauth2client==4.1.3
# oauthlib==3.2.0
# okgrade==0.4.3
# opencv-contrib-python==4.1.2.30
# opencv-python==4.1.2.30
# openpyxl==3.0.10
# opt-einsum==3.3.0
# osqp==0.6.2.post0
# packaging==21.3
# palettable==3.3.0
# pandas==1.3.5
# pandas-datareader==0.9.0
# pandas-gbq==0.13.3
# pandas-profiling==1.4.1
# pandocfilters==1.5.0
# panel==0.12.1
# param==1.12.2
# parso==0.8.3
# pathlib==1.0.1
# pathy==0.6.2
# patsy==0.5.2
# pep517==0.12.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.1.2
# pip-tools==6.2.0
# plotly==5.5.0
# plotnine==0.6.0
# pluggy==0.7.1
# pooch==1.6.0
# portpicker==1.3.9
# prefetch-generator==1.0.1
# preshed==3.0.6
# prettytable==3.3.0
# progressbar2==3.38.0
# prometheus-client==0.14.1
# promise==2.3
# prompt-toolkit==1.0.18
# protobuf==3.17.3
# psutil==5.4.8
# psycopg2==2.7.6.1
# ptyprocess==0.7.0
# py==1.11.0
# pyarrow==6.0.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.4
# pycparser==2.21
# pyct==0.4.8
# pydantic==1.8.2
# pydata-google-auth==1.4.0
# pydot==1.3.0
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyemd==0.5.1
# pyerfa==2.0.0.1
# pyglet==1.5.0
# Pygments==2.6.1
# pygobject==3.26.1
# pymc3==3.11.5
# PyMeeus==0.5.11
# pymongo==4.1.1
# pymystem3==0.2.0
# PyOpenGL==3.1.6
# pyparsing==3.0.9
# pyrsistent==0.18.1
# pysndfile==1.3.8
# PySocks==1.7.1
# pystan==2.19.1.1
# pytest==3.6.4
# python-apt==0.0.0
# python-chess==0.23.11
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==6.1.2
# python-utils==3.3.3
# pytz==2022.1
# PyVirtualDisplay==3.0
# pyviz-comms==2.2.0
# PyWavelets==1.3.0
# PyYAML==3.13
# pyzmq==23.2.0
# qdldl==0.1.5.post2
# qtconsole==5.3.1
# QtPy==2.1.0
# regex==2022.6.2
# requests==2.23.0
# requests-oauthlib==1.3.1
# resampy==0.3.1
# rpy2==3.4.5
# rsa==4.8
# scikit-image==0.18.3
# scikit-learn==1.0.2
# scipy==1.7.3
# screen-resolution-extra==0.0.0
# scs==3.2.0
# seaborn==0.11.2
# semver==2.13.0
# Send2Trash==1.8.0
# setuptools-git==1.2
# Shapely==1.8.2
# simplegeneric==0.8.1
# six==1.15.0
# sklearn==0.0
# sklearn-pandas==1.8.0
# smart-open==5.2.1
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# SoundFile==0.10.3.post1
# soupsieve==2.3.2.post1
# spacy==3.3.1
# spacy-legacy==3.0.9
# spacy-loggers==1.0.2
# Sphinx==1.8.6
# sphinxcontrib-serializinghtml==1.1.5
# sphinxcontrib-websupport==1.2.4
# SQLAlchemy==1.4.39
# sqlparse==0.4.2
# srsly==2.4.3
# statsmodels==0.10.2
# sympy==1.7.1
# tables==3.7.0
# tabulate==0.8.10
# tblib==1.7.0
# tenacity==8.0.1
# tensorboard==2.8.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.1
# tensorflow==2.8.2+zzzcolab20220527125636
# tensorflow-datasets==4.0.1
# tensorflow-estimator==2.8.0
# tensorflow-gcs-config==2.8.0
# tensorflow-hub==0.12.0
# tensorflow-io-gcs-filesystem==0.26.0
# tensorflow-metadata==1.9.0
# tensorflow-probability==0.16.0
# termcolor==1.1.0
# terminado==0.13.3
# testpath==0.6.0
# text-unidecode==1.3
# textblob==0.15.3
# Theano-PyMC==1.1.2
# thinc==8.0.17
# threadpoolctl==3.1.0
# tifffile==2021.11.2
# tinycss2==1.1.1
# tomli==2.0.1
# toolz==0.12.0
# torch==1.8.1
# torchaudio @ https://download.pytorch.org/whl/cu113/torchaudio-0.12.0%2Bcu113-cp37-cp37m-linux_x86_64.whl
# torchsummary==1.5.1
# torchtext==0.13.0
# torchvision @ https://download.pytorch.org/whl/cu113/torchvision-0.13.0%2Bcu113-cp37-cp37m-linux_x86_64.whl
# tornado==5.1.1
# tqdm==4.64.0
# traitlets==5.1.1
# tweepy==3.10.0
# typeguard==2.7.1
# typer==0.4.2
# typing-extensions==4.1.1
# tzlocal==1.5.1
# uritemplate==3.0.1
# urllib3==1.24.3
# vega-datasets==0.9.0
# wasabi==0.9.1
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==1.0.1
# widgetsnbextension==3.6.1
# wordcloud==1.5.0
# wrapt==1.14.1
# xarray==0.20.2
# xarray-einstats==0.2.2
# xgboost==0.90
# xkit==0.0.0
# xlrd==1.1.0
# xlwt==1.3.0
# yellowbrick==1.4
# zict==2.2.0
# zipp==3.8.0

# %% [markdown]
# ## 什麼是 Lunar Lander？
#
# “LunarLander-v2” 這個環境是在模擬登月小艇降落在月球表面時的情形。
# 這個任務的目標是讓登月小艇「安全地」降落在兩個黃色旗幟間的平地上。
# > Landing pad is always at coordinates (0,0).
# > Coordinates are the first two numbers in state vector.
#
# ![](https://gym.openai.com/assets/docs/aeloop-138c89d44114492fd02822303e6b4b07213010bb14ca5856d2d49d6b62d88e53.svg)
#
# 所謂的「環境」其實同時包括了 agent 和 environment。
# 我們利用 `step()` 這個函式讓 agent 行動，而後函式便會回傳 environment 給予的 observation/state（以下這兩個名詞代表同樣的意思）和 reward。

# %% [markdown]
# ### Observation / State
#
# 首先，我們可以看看 environment 回傳給 agent 的 observation 究竟是長什麼樣子的資料：

# %%
print(env.observation_space)
# Out:
# Box(-inf, inf, (8,), float32)

# %% [markdown]
# `Box(8,)` 說明我們會拿到 8 維的向量作為 observation，其中包含：垂直及水平座標、速度、角度、加速度等等，這部分我們就不細說。
#
# ### Action
#
# 而在 agent 得到 observation 和 reward 以後，能夠採取的動作有：

# %%
print(env.action_space)
# Out:
# Discrete(4)

# %% [markdown]
# `Discrete(4)` 說明 agent 可以採取四種離散的行動：
# - 0 代表不採取任何行動
# - 2 代表主引擎向下噴射
# - 1, 3 則是向左右噴射
#
# 接下來，我們嘗試讓 agent 與 environment 互動。
# 在進行任何操作前，建議先呼叫 `reset()` 函式讓整個「環境」重置。
# 而這個函式同時會回傳「環境」最初始的狀態。

# %%
initial_state = env.reset()
print(initial_state)
# Out:
# [ 0.00396109  1.4083536   0.40119505 -0.11407257 -0.00458307 -0.09087662
#   0.          0.        ]

# %% [markdown]
# 接著，我們試著從 agent 的四種行動空間中，隨機採取一個行動

# %%
random_action = env.action_space.sample()
print(random_action)
# Out:
# 0

# %% [markdown]
# 再利用 `step()` 函式讓 agent 根據我們隨機抽樣出來的 `random_action` 動作。
# 而這個函式會回傳四項資訊：
# - observation / state
# - reward
# - 完成與否
# - 其餘資訊

# %%
observation, reward, done, info = env.step(random_action)

# %% [markdown]
# 第一項資訊 `observation` 即為 agent 採取行動之後，agent 對於環境的 observation 或者說環境的 state 為何。
# 而第三項資訊 `done` 則是 `True` 或 `False` 的布林值，當登月小艇成功著陸或是不幸墜毀時，代表這個回合（episode）也就跟著結束了，此時 `step()` 函式便會回傳 `done = True`，而在那之前，`done` 則保持 `False`。

# %%
print(done)
# Out:
# False

# %% [markdown]
# ### Reward
#
# 而「環境」給予的 reward 大致是這樣計算：
# - 小艇墜毀得到 -100 分
# - 小艇在黃旗幟之間成功著地則得 100~140 分
# - 噴射主引擎（向下噴火）每次 -0.3 分
# - 小艇最終完全靜止則再得 100 分
# - 小艇每隻腳碰觸地面 +10 分
#
# > Reward for moving from the top of the screen to landing pad and zero speed is about 100..140 points.
# > If lander moves away from landing pad it loses reward back.
# > Episode finishes if the lander crashes or comes to rest, receiving additional -100 or +100 points.
# > Each leg ground contact is +10.
# > Firing main engine is -0.3 points each frame.

# %%
print(reward) # after doing a random action (0), the immediate reward is stored in this
# Out:
# -0.8588900517154912

# %% [markdown]
# ### Random Agent
#
# 最後，在進入實做之前，我們就來看看這樣一個 random agent 能否成功登陸月球：

# %%
env.reset()

img = plt.imshow(env.render(mode='rgb_array'))

done = False
while not done:
    action = env.action_space.sample()
    observation, reward, done, _ = env.step(action)

    img.set_data(env.render(mode='rgb_array'))
    display.display(plt.gcf())
    display.clear_output(wait=True)

# %% [markdown]
# ## DQN
#
# 現在來搭建一個簡單的 policy network。
# 我們預設模型的輸入是 8-dim 的 observation，輸出則是離散的四個動作之一：

# %%
class DQN(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size=8, action_size=4, fc1_units=64, fc2_units=64):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)

    def forward(self, state):
        """Build a network that maps state -> action values."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# 再來，搭建一個簡單的 agent，並搭配上方的 policy network 來採取行動。
# 這個 agent 能做到以下幾件事：
# - `learn()`：從記下來的 log probabilities 及 rewards 來更新 policy network。
# - `sample()`：從 environment 得到 observation 之後，利用 policy network 得出應該採取的行動。
# 而此函式除了回傳抽樣出來的 action，也會回傳此次抽樣的 log probabilities。

# %%
from collections import namedtuple

class ReplayMemory:
    """Fixed-size buffer to store experience tuples."""
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  
        self.memory = []  
        self.index = 0  
        self.transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))
        
    def push(self, state, action, state_next, reward):
        """Push a new experience to memory."""
        if len(self.memory) < self.capacity: # if still has capacity, initialize memory[index] to None
            self.memory.append(None)

        self.memory[self.index] = self.transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity  # circular index

    def sample(self, batch_size):
        """Randomly sample a batch of experiences from memory."""
        return random.sample(self.memory, batch_size)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
class DQNAgent():
    """Interacts with and learns from the environment."""
    def __init__(self, num_states, num_actions):
        """Initialize an Agent object."""
        
        self.num_states = num_states
        self.num_actions = num_actions
        
        # Replay memory
        self.memory_capacity = 10000
        self.memory = ReplayMemory(self.memory_capacity)
        
        # Q-Network
        self.main_q_network = DQN() 
        self.target_q_network = DQN()
        
        # optimizer
        self.optimizer = optim.RMSprop(self.main_q_network.parameters(), lr=1e-4)
    
    def update_q_function(self):
        '''update q function'''
        
        # no enough samples, just return
        if len(self.memory) < BATCH_SIZE:
            return
        # If enough samples are available in memory, get random subset and learn
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()
        
        self.expected_state_action_values = self.get_expected_state_action_values()

        self.update_main_q_network()

    def make_minibatch(self):
        '''Creating a mini-batch'''

        transitions = self.memory.sample(BATCH_SIZE)

        Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))
        batch = Transition(*zip(*transitions))


        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''calculate Q（St,at）'''

        self.main_q_network.eval()
        self.target_q_network.eval()

        self.state_action_values = self.main_q_network(
            self.state_batch).gather(1, self.action_batch)

        non_final_mask = torch.BoolTensor(tuple(map(lambda s: s is not None,
                                                    self.batch.next_state)))
        # set all state to 0
        next_state_values = torch.zeros(BATCH_SIZE)

        next_state_values[non_final_mask] = self.target_q_network(
            self.non_final_next_states).max(1)[0].detach()
        # DQN formula
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values
        
        return expected_state_action_values 
        
    def get_action(self, state, episode, test=False):
        """Returns actions for given state as per current policy."""
        if test:
            self.main_q_network.eval()
            with torch.no_grad():
                # t.max(1) will return largest column value of each row.
                # second column on max result is index of where max element was
                # found, so we pick action with the larger expected reward.
                action = self.main_q_network(torch.from_numpy(state).unsqueeze(0)).max(1)[1].view(1, 1)
            return action.item()
        
        global steps_done
        # Epsilon-greedy policy
        #epsilon = episode
        #epsilon = 0.5 * (1 / (episode + 1))
        epsilon = EPS_END + (EPS_START - EPS_END) * \
                np.exp(-1. * steps_done / EPS_DECAY)
        #print('epsilon', epsilon)
        
        steps_done += 1
        
        if epsilon <= np.random.uniform(0, 1):
            #print('use max')
            self.main_q_network.eval()
            with torch.no_grad():
                # t.max(1) will return largest column value of each row.
                # second column on max result is index of where max element was
                # found, so we pick action with the larger expected reward.
                action = self.main_q_network(state).max(1)[1].view(1, 1)
        else:
            #print('random')
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  
            
        return action

    def update_main_q_network(self):
        
        '''update main q net'''

        # set train mode
        self.main_q_network.train()
        # Hurberloss function
        # expected_state_action_values (minbatch,)->(minbatchx1)

        loss = F.smooth_l1_loss(self.state_action_values,
                                self.expected_state_action_values.unsqueeze(1))

        # update
        self.optimizer.zero_grad()  # reset gradient
        loss.backward()  # backpropagation
        for param in self.main_q_network.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()  # update network


    def memorize(self, state, action, state_next, reward):
        '''save state, action, state_next, reward into replay memory'''
        self.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        
        '''synchronize Target Q-Network to Main Q-Network'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %% [markdown]
# 最後，建立一個 network 和 agent，就可以開始進行訓練了。

# %%
network = DQN()
agent = DQNAgent(env.observation_space.shape[0], env.action_space.n)

# %% [markdown]
# ## 訓練 Agent
#
# 現在我們開始訓練 agent。
# 透過讓 agent 和 environment 互動，我們記住每一組對應的 log probabilities 及 reward，並在成功登陸或者不幸墜毀後，回放這些「記憶」來訓練 policy network。

# %%
EPISODE_PER_BATCH = 5  # 每蒐集 5 個 episodes 更新一次 agent
NUM_BATCH = 600        # 總共更新 400 次
BATCH_SIZE = 32
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200

best_score = 0
best_batch = 0

# 訓練前，先確保 network 處在 training 模式
agent.main_q_network.train()
agent.target_q_network.train()
steps_done = 0

avg_total_rewards, avg_final_rewards = [], []

prg_bar = tqdm(range(NUM_BATCH))
for batch in prg_bar:

    rewards = []
    total_rewards, final_rewards = [], []

    # 蒐集訓練資料
    for episode in range(EPISODE_PER_BATCH):
        
        observation = env.reset() # 環境的初始化
        state = observation  # 將觀測結果直接當成狀態s使用
        state = torch.from_numpy(state).type(
                torch.FloatTensor)  # 將NumPy變數轉換成PyTorch的張量
        state = torch.unsqueeze(state, 0)  # 將size 4轉換成size 1x4
        total_reward, total_step = 0, 0

        while True:

            action = agent.get_action(state, batch)  # 求出動作
            # 執行動作a_t後，算出s_{t+1}與done旗標
            # 根據action指定.item()、再取得內容
            observation_next, reward, done, _ = env.step(action.item())  # 不會用到info，所以設定為_

            total_reward += reward
            total_step += 1
            rewards.append(reward) #改這裡
            # ! 重要 ！
            # 現在的reward 的implementation 為每個時刻的瞬時reward, 給定action_list : a1, a2, a3 ......
            #                                                       reward :     r1, r2 ,r3 ......
            # medium：將reward調整成accumulative decaying reward, 給定action_list : a1,                         a2,                           a3 ......
            #                                                       reward :     r1+0.99*r2+0.99^2*r3+......, r2+0.99*r3+0.99^2*r4+...... ,r3+0.99*r4+0.99^2*r5+ ......
            # boss : implement DQN
            if done:
                state_next = None  # 沒有下個狀態，所以存入None

            else:
                state_next = observation_next  # 直接將觀測結果當成狀態使用
                state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # 將numpy變數轉換成PyTorch的張量
                state_next = torch.unsqueeze(state_next, 0)  # 將size 4轉換成size 1x4
                
            # 將學習經驗存入記憶體
            agent.memorize(state, action, state_next, torch.FloatTensor([reward]))
            
            # 以Experience Replay更新Q函數
            agent.update_q_function()
            
            # 觀測狀態的更新
            state = state_next
            
            # 結束時的處理
            if done:
                final_rewards.append(reward)
                total_rewards.append(total_reward)
                break
                

    #print(f"rewards looks like ", np.shape(rewards))      
    # 紀錄訓練過程
    avg_total_reward = sum(total_rewards) / len(total_rewards)
    avg_final_reward = sum(final_rewards) / len(final_rewards)
    avg_total_rewards.append(avg_total_reward)
    avg_final_rewards.append(avg_final_reward)
    prg_bar.set_description(f"Total: {avg_total_reward: 4.1f}, Final: {avg_final_reward: 4.1f}")

    # 更新網路
    # rewards = np.concatenate(rewards, axis=0)
    #rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-9)  # 將 reward 正規標準化
    agent.update_target_q_function()
    print("torch.from_numpy(rewards) looks like ", torch.from_numpy(np.array(rewards)).size())


    ### testing

    fix(env, seed)
    agent.main_q_network.eval()  # 測試前先將 network 切換為 evaluation 模式
    NUM_OF_TEST = 5 # Do not revise it !!!!!
    test_total_reward = []
    action_list = []
    for i in range(NUM_OF_TEST):
        actions = []
        state = env.reset()

        #img = plt.imshow(env.render(mode='rgb_array'))

        total_reward = 0

        done = False
        while not done:
            action = agent.get_action(state, episode=i, test=True)
            actions.append(action)
            state, reward, done, _ = env.step(action)

            total_reward += reward

            #img.set_data(env.render(mode='rgb_array'))
            #display.display(plt.gcf())
            #display.clear_output(wait=True)
        print(total_reward)
        test_total_reward.append(total_reward)

        action_list.append(actions) #儲存你測試的結果
        print("length of actions is ", len(actions))
    print(f"Your final reward is : %.2f"%np.mean(test_total_reward))
    if np.mean(test_total_reward) > 250:
        distribution = {}
        for actions in action_list:
            for action in actions:
                if action not in distribution.keys():
                    distribution[action] = 1
                else:
                    distribution[action] += 1
        PATH = "Action_List_test" + str(batch) + ".npy" # 可以改成你想取的名字或路徑
        np.save(PATH ,np.array(action_list)) 
        if np.mean(test_total_reward) > best_score:
            best_score = np.mean(test_total_reward)
            best_batch = batch
            print('Improve to score %.2f at batch %d'% (best_score, best_batch ))
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# torch.from_numpy(rewards) looks like  torch.Size([712])
# -196.5292340798315
# length of actions is  65
# -248.4060791636938
# length of actions is  66
# -229.0882009391201
# length of actions is  68
# -240.0468410449334
# length of actions is  67
# -364.3726309414928
# length of actions is  79
# Your final reward is : -255.69
# /usr/local/lib/python3.7/dist-packages/torch/__init__.py:422: UserWarning: torch.set_deterministic is deprecated and will be removed in a future release. Please use torch.use_deterministic_algorithms instead
#   "torch.set_deterministic is deprecated and will be removed in a future "
# torch.from_numpy(rewards) looks like  torch.Size([358])
# -295.80096012708566
# length of actions is  64
# -398.18011003102254
# length of actions is  76
# -312.4317717193137
# length of actions is  66
# -109.81622709782555
# length of actions is  76
# -113.36256609710372
# length of actions is  64
# Your final reward is : -245.92
# torch.from_numpy(rewards) looks like  torch.Size([373])
# -211.20014515260644
# length of actions is  65
# -78.97505840467004
# length of actions is  73
# -213.0882867476982
# length of actions is  52
# -197.56959249021003
# length of actions is  86
# -242.39172824198
# length of actions is  64
# Your final reward is : -188.64
# torch.from_numpy(rewards) looks like  torch.Size([534])
# -118.02922148881689
# length of actions is  152
# 78.53997632164662
# length of actions is  1000
# 12.507114424198392
# length of actions is  163
# 245.26813575122577
# length of actions is  266
# 10.266348106086127
# length of actions is  192
# Your final reward is : 45.71
# torch.from_numpy(rewards) looks like  torch.Size([3456])
# -443.01542022254193
# length of actions is  204
# -270.33337082447156
# length of actions is  252
# -444.66456085761155
# length of actions is  333
# -295.17125880774023
# length of actions is  187
# -164.57164459688568
# length of actions is  227
# Your final reward is : -323.55
# torch.from_numpy(rewards) looks like  torch.Size([1118])
# -370.7600330414103
# length of actions is  175
# -546.2358029810446
# length of actions is  214
# -462.4728981861137
# length of actions is  187
# -485.33744572449245
# length of actions is  246
# -365.02130643932037
# length of actions is  107
# Your final reward is : -445.97
# torch.from_numpy(rewards) looks like  torch.Size([1047])
# -423.6430159131486
# length of actions is  176
# -303.77047727030435
# length of actions is  219
# -228.63764781751706
# length of actions is  166
# -417.84183242155956
# length of actions is  240
# -409.06994973862464
# length of actions is  162
# Your final reward is : -356.59
# torch.from_numpy(rewards) looks like  torch.Size([1601])
# -790.0874309394575
# length of actions is  173
# -755.9117267618029
# length of actions is  186
# -900.587132335938
# length of actions is  164
# -674.1979461386102
# length of actions is  171
# -770.7198675639231
# length of actions is  235
# Your final reward is : -778.30
# torch.from_numpy(rewards) looks like  torch.Size([3216])
# -300.21590165776666
# length of actions is  370
# -182.59582360747277
# length of actions is  555
# -364.75076125554637
# length of actions is  775
# -503.4098096134312
# length of actions is  718
# -275.0380972436823
# length of actions is  246
# Your final reward is : -325.20
# torch.from_numpy(rewards) looks like  torch.Size([2628])
# -56.43325335051232
# length of actions is  266
# -396.1253591101103
# length of actions is  294
# 148.6124610216784
# length of actions is  574
# 78.40947702974756
# length of actions is  1000
# -133.6167859228018
# length of actions is  1000
# Your final reward is : -71.83
# torch.from_numpy(rewards) looks like  torch.Size([2661])
# -224.30991012260878
# length of actions is  395
# 64.92381872189704
# length of actions is  1000
# -45.526039396799874
# length of actions is  256
# 170.63771515302267
# length of actions is  897
# 76.66820908530816
# length of actions is  1000
# Your final reward is : 8.48
# torch.from_numpy(rewards) looks like  torch.Size([2969])
# 169.8986955455228
# length of actions is  602
# -11.494655690160627
# length of actions is  251
# 90.00054527465073
# length of actions is  1000
# 223.20301912408135
# length of actions is  371
# 39.236161514517526
# length of actions is  1000
# Your final reward is : 102.17
# torch.from_numpy(rewards) looks like  torch.Size([3052])
# 173.5410810347937
# length of actions is  606
# -168.8340837862458
# length of actions is  239
# -149.9636078992219
# length of actions is  303
# -146.86737973121976
# length of actions is  1000
# -61.01301192986467
# length of actions is  354
# Your final reward is : -70.63
# torch.from_numpy(rewards) looks like  torch.Size([3236])
# 75.243430299123
# length of actions is  1000
# -8.511180629118783
# length of actions is  366
# -20.946493525516516
# length of actions is  307
# -133.97268021256937
# length of actions is  1000
# 216.23296613528123
# length of actions is  581
# Your final reward is : 25.61
# torch.from_numpy(rewards) looks like  torch.Size([2070])
# 55.8321313905866
# length of actions is  1000
# -18.922999386313307
# length of actions is  363
# 107.20359389731523
# length of actions is  1000
# -150.37940649696264
# length of actions is  1000
# -20.775644834892773
# length of actions is  317
# Your final reward is : -5.41
# torch.from_numpy(rewards) looks like  torch.Size([3670])
# -128.54001456697463
# length of actions is  1000
# 100.32951033214614
# length of actions is  1000
# -111.23617772423607
# length of actions is  1000
# -122.9795610720102
# length of actions is  1000
# -174.58420728885403
# length of actions is  1000
# Your final reward is : -87.40
# torch.from_numpy(rewards) looks like  torch.Size([4225])
# -132.46575096220184
# length of actions is  1000
# -94.31824308357196
# length of actions is  1000
# -108.33135527041311
# length of actions is  1000
# -128.7118593205286
# length of actions is  1000
# -163.92473601959512
# length of actions is  1000
# Your final reward is : -125.55
# torch.from_numpy(rewards) looks like  torch.Size([3197])
# -131.8127738595782
# length of actions is  1000
# -82.67180090735745
# length of actions is  1000
# -98.7176229474237
# length of actions is  1000
# -121.7655488705628
# length of actions is  1000
# -163.91921235291997
# length of actions is  1000
# Your final reward is : -119.78
# torch.from_numpy(rewards) looks like  torch.Size([4296])
# -135.14570258669713
# length of actions is  1000
# -74.08171560355791
# length of actions is  1000
# -90.52407360958776
# length of actions is  1000
# -122.10873466858135
# length of actions is  1000
# -164.73464798224546
# length of actions is  1000
# Your final reward is : -117.32
# torch.from_numpy(rewards) looks like  torch.Size([3613])
# -107.04308257616357
# length of actions is  1000
# -70.79180236418034
# length of actions is  1000
# -71.96269135872932
# length of actions is  1000
# -106.19374498900808
# length of actions is  1000
# -159.59942129145568
# length of actions is  1000
# Your final reward is : -103.12
# torch.from_numpy(rewards) looks like  torch.Size([4740])
# -125.27890774958296
# length of actions is  1000
# -61.45106725160651
# length of actions is  1000
# -61.27910347644071
# length of actions is  1000
# -114.6863976766304
# length of actions is  1000
# -159.32588595146362
# length of actions is  1000
# Your final reward is : -104.40
# torch.from_numpy(rewards) looks like  torch.Size([4577])
# -114.61928498353666
# length of actions is  1000
# -37.79369791178841
# length of actions is  1000
# -46.019438634525365
# length of actions is  1000
# -116.00843839533702
# length of actions is  1000
# -150.90769689235776
# length of actions is  1000
# Your final reward is : -93.07
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -115.115704238473
# length of actions is  1000
# -51.650930882529266
# length of actions is  1000
# -58.67460219656388
# length of actions is  1000
# -116.76407967719828
# length of actions is  1000
# -153.71472094970113
# length of actions is  1000
# Your final reward is : -99.18
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -113.41847636756093
# length of actions is  1000
# 63.88334428977298
# length of actions is  1000
# 38.485392375647486
# length of actions is  1000
# -115.26661316872797
# length of actions is  1000
# -138.22147407980486
# length of actions is  1000
# Your final reward is : -52.91
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -103.16777788799376
# length of actions is  1000
# 78.37915018369968
# length of actions is  1000
# 32.55489882018913
# length of actions is  1000
# -106.98935058900184
# length of actions is  1000
# -110.75657820769285
# length of actions is  1000
# Your final reward is : -42.00
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -104.68821487930484
# length of actions is  1000
# 78.07790391903458
# length of actions is  1000
# 34.74900389410206
# length of actions is  1000
# -107.21006432982948
# length of actions is  1000
# -118.42488303448205
# length of actions is  1000
# Your final reward is : -43.50
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -84.6330212148694
# length of actions is  1000
# 96.90659512525694
# length of actions is  1000
# 156.32802020906644
# length of actions is  697
# -47.712624729609175
# length of actions is  1000
# -59.26026451226008
# length of actions is  1000
# Your final reward is : 12.33
# torch.from_numpy(rewards) looks like  torch.Size([4098])
# -77.69250430478797
# length of actions is  1000
# 44.35268466982692
# length of actions is  1000
# 106.60954009995885
# length of actions is  961
# -95.94381449236754
# length of actions is  1000
# -73.22172471744597
# length of actions is  1000
# Your final reward is : -19.18
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -65.9689943778714
# length of actions is  1000
# 37.759066043771234
# length of actions is  1000
# 110.75393392490672
# length of actions is  849
# -68.30628296615568
# length of actions is  1000
# -32.96567458213728
# length of actions is  1000
# Your final reward is : -3.75
# torch.from_numpy(rewards) looks like  torch.Size([5000])
# -53.534738687356345
# length of actions is  1000
# 7.345859240268918
# length of actions is  1000
# 153.82352828949377
# length of actions is  539
# -53.435311799825904
# length of actions is  1000
# 73.97670602198568
# length of actions is  815
# Your final reward is : 25.64
# torch.from_numpy(rewards) looks like  torch.Size([4607])
# -58.009401538922305
# length of actions is  1000
# -79.85557488216318
# length of actions is  354
# -140.59573207800668
# length of actions is  423
# 144.7191083314496
# length of actions is  467
# 178.37365246492413
# length of actions is  592
# Your final reward is : 8.93
# torch.from_numpy(rewards) looks like  torch.Size([3476])
# -36.69062581086317
# length of actions is  1000
# -55.77455658262352
# length of actions is  222
# 5.841537280607677
# length of actions is  1000
# -44.21187213142875
# length of actions is  1000
# -121.30519750176396
# length of actions is  890
# Your final reward is : -50.43
# torch.from_numpy(rewards) looks like  torch.Size([2645])
# 88.1680917930452
# length of actions is  879
# -48.60911365019514
# length of actions is  208
# -82.73164771110989
# length of actions is  171
# 126.3668325150928
# length of actions is  405
# 93.31404576806482
# length of actions is  913
# Your final reward is : 35.30
# torch.from_numpy(rewards) looks like  torch.Size([3312])
# 108.86547104463402
# length of actions is  573
# -91.31102281325298
# length of actions is  223
# 64.7775055169431
# length of actions is  924
# -76.70567567923908
# length of actions is  188
# -77.1431744232904
# length of actions is  228
# Your final reward is : -14.30
# torch.from_numpy(rewards) looks like  torch.Size([2183])
# 136.51267733827808
# length of actions is  424
# -50.210514760843836
# length of actions is  184
# 45.786789982982825
# length of actions is  1000
# -75.53428848932175
# length of actions is  167
# 137.2409117630449
# length of actions is  482
# Your final reward is : 38.76
# torch.from_numpy(rewards) looks like  torch.Size([1257])
# -61.03299147245865
# length of actions is  130
# -51.506013867382805
# length of actions is  95
# -27.214880925453272
# length of actions is  158
# 155.691296970901
# length of actions is  318
# 170.92541735018722
# length of actions is  320
# Your final reward is : 37.37
# torch.from_numpy(rewards) looks like  torch.Size([2347])
# -76.08913703583627
# length of actions is  114
# -69.86161000105963
# length of actions is  175
# 165.12608361522706
# length of actions is  524
# 38.933343978502506
# length of actions is  1000
# -53.81229472080457
# length of actions is  89
# Your final reward is : 0.86
# torch.from_numpy(rewards) looks like  torch.Size([1010])
# -56.56565869677141
# length of actions is  127
# -57.1214650798361
# length of actions is  110
# -32.27842260659253
# length of actions is  191
# -101.64318556313162
# length of actions is  235
# -49.575137677724
# length of actions is  151
# Your final reward is : -59.44
# torch.from_numpy(rewards) looks like  torch.Size([670])
# -69.25537640697142
# length of actions is  124
# -40.695061477195864
# length of actions is  231
# -67.00855304131555
# length of actions is  210
# -125.05405183277547
# length of actions is  148
# -75.54103580259269
# length of actions is  403
# Your final reward is : -75.51
# torch.from_numpy(rewards) looks like  torch.Size([1176])
# -62.38632871937598
# length of actions is  136
# -41.69032628545194
# length of actions is  109
# -71.15950465064616
# length of actions is  245
# 175.47386862607271
# length of actions is  514
# -77.82929813889844
# length of actions is  152
# Your final reward is : -15.52
# torch.from_numpy(rewards) looks like  torch.Size([1544])
# -59.65712774983026
# length of actions is  154
# -49.8854376825805
# length of actions is  118
# -43.07646617202438
# length of actions is  174
# 166.21138319737443
# length of actions is  401
# -56.20893346443406
# length of actions is  151
# Your final reward is : -8.52
# torch.from_numpy(rewards) looks like  torch.Size([1413])
# -78.94983180087242
# length of actions is  155
# -73.22411915096157
# length of actions is  184
# -22.93683247793868
# length of actions is  179
# -56.67687477055218
# length of actions is  183
# 155.73255809684042
# length of actions is  354
# Your final reward is : -15.21
# torch.from_numpy(rewards) looks like  torch.Size([1385])
# 170.62984574043548
# length of actions is  226
# -80.65132434113387
# length of actions is  294
# -82.0123020401156
# length of actions is  212
# 192.98136892794673
# length of actions is  470
# -106.67674268187164
# length of actions is  213
# Your final reward is : 18.85
# torch.from_numpy(rewards) looks like  torch.Size([1590])
# -60.89396917125936
# length of actions is  163
# -22.8757461222541
# length of actions is  141
# -50.26072298518173
# length of actions is  157
# 187.91920614671972
# length of actions is  493
# -35.59973655343491
# length of actions is  160
# Your final reward is : 3.66
# torch.from_numpy(rewards) looks like  torch.Size([1326])
# -58.591648458413914
# length of actions is  157
# -107.52876673081795
# length of actions is  339
# -71.1084730214498
# length of actions is  160
# 168.64001704075903
# length of actions is  328
# -73.85228351388014
# length of actions is  185
# Your final reward is : -28.49
# torch.from_numpy(rewards) looks like  torch.Size([2149])
# -68.4112871580133
# length of actions is  156
# 129.54228669245583
# length of actions is  481
# 94.60947754968137
# length of actions is  703
# -65.22958305892831
# length of actions is  166
# -138.88614497599707
# length of actions is  205
# Your final reward is : -9.68
# torch.from_numpy(rewards) looks like  torch.Size([2331])
# 171.98384503785496
# length of actions is  261
# 157.95930858964678
# length of actions is  370
# 180.15577602843413
# length of actions is  488
# -78.26186736985191
# length of actions is  289
# -132.019693483397
# length of actions is  203
# Your final reward is : 59.96
# torch.from_numpy(rewards) looks like  torch.Size([2871])
# 160.36577961712146
# length of actions is  230
# 92.6072710033232
# length of actions is  1000
# 180.28791847050218
# length of actions is  372
# 31.961818046067705
# length of actions is  1000
# 107.40671448053767
# length of actions is  692
# Your final reward is : 114.53
# torch.from_numpy(rewards) looks like  torch.Size([2629])
# 166.05980648038832
# length of actions is  446
# -74.57723537685168
# length of actions is  156
# -77.97131058264887
# length of actions is  236
# 138.29149338623705
# length of actions is  422
# -74.21721544928161
# length of actions is  165
# Your final reward is : 15.52
# torch.from_numpy(rewards) looks like  torch.Size([2757])
# 163.81778356591542
# length of actions is  373
# -69.9489320764422
# length of actions is  171
# 142.9118236890743
# length of actions is  492
# -66.19780330520821
# length of actions is  239
# 103.23205026049789
# length of actions is  1000
# Your final reward is : 54.76
# torch.from_numpy(rewards) looks like  torch.Size([1736])
# 162.6121956880124
# length of actions is  385
# 148.4902960036496
# length of actions is  605
# 175.87803166415483
# length of actions is  324
# 170.86423755771972
# length of actions is  268
# 176.356558830699
# length of actions is  641
# Your final reward is : 166.84
# torch.from_numpy(rewards) looks like  torch.Size([2322])
# 163.47192938873468
# length of actions is  252
# 212.38851727986167
# length of actions is  368
# 125.6059916083218
# length of actions is  719
# 201.36805818291919
# length of actions is  200
# 163.8714807561102
# length of actions is  471
# Your final reward is : 173.34
# torch.from_numpy(rewards) looks like  torch.Size([2293])
# 161.986560081424
# length of actions is  260
# 37.3313151605949
# length of actions is  1000
# -45.598296832803214
# length of actions is  254
# -156.23494287055064
# length of actions is  252
# 169.7476162619854
# length of actions is  383
# Your final reward is : 33.45
# torch.from_numpy(rewards) looks like  torch.Size([2928])
# 172.74798892449485
# length of actions is  221
# -31.714430661772994
# length of actions is  151
# 111.875133626509
# length of actions is  558
# -53.008272768413725
# length of actions is  160
# 180.6441270761907
# length of actions is  546
# Your final reward is : 76.11
# torch.from_numpy(rewards) looks like  torch.Size([1674])
# 168.81166727288485
# length of actions is  268
# 74.67171758193027
# length of actions is  1000
# 169.0775539958786
# length of actions is  659
# -60.768309931008645
# length of actions is  237
# -89.94220490269595
# length of actions is  269
# Your final reward is : 52.37
# torch.from_numpy(rewards) looks like  torch.Size([1972])
# 160.66422779923272
# length of actions is  305
# -81.43043051643635
# length of actions is  297
# -21.18581157289647
# length of actions is  281
# -62.48623996939483
# length of actions is  182
# 150.7198234352252
# length of actions is  803
# Your final reward is : 29.26
# torch.from_numpy(rewards) looks like  torch.Size([2847])
# 53.835264553853165
# length of actions is  1000
# 146.952673918114
# length of actions is  430
# 177.26390648303177
# length of actions is  507
# -58.04964374665546
# length of actions is  1000
# 140.813438027145
# length of actions is  575
# Your final reward is : 92.16
# torch.from_numpy(rewards) looks like  torch.Size([3274])
# 150.51871108974578
# length of actions is  357
# 90.93442785713175
# length of actions is  743
# 114.33667281002252
# length of actions is  654
# 198.04107334552634
# length of actions is  379
# 169.74098270521023
# length of actions is  594
# Your final reward is : 144.71
# torch.from_numpy(rewards) looks like  torch.Size([1653])
# 173.0468399367156
# length of actions is  218
# 28.856896556396862
# length of actions is  283
# -63.391697119075125
# length of actions is  419
# -65.1024880256239
# length of actions is  156
# 201.49334250574805
# length of actions is  476
# Your final reward is : 54.98
# torch.from_numpy(rewards) looks like  torch.Size([2253])
# 31.65369713504448
# length of actions is  1000
# -82.61667265794176
# length of actions is  493
# -13.971177805795383
# length of actions is  1000
# 188.44474961571208
# length of actions is  359
# -40.040919369992295
# length of actions is  134
# Your final reward is : 16.69
# torch.from_numpy(rewards) looks like  torch.Size([2330])
# 27.028658562752433
# length of actions is  1000
# -82.18463859444753
# length of actions is  442
# 81.46309130605498
# length of actions is  1000
# -72.69538370705204
# length of actions is  182
# 197.38426366993497
# length of actions is  496
# Your final reward is : 30.20
# torch.from_numpy(rewards) looks like  torch.Size([3214])
# 44.633409886225934
# length of actions is  1000
# 128.8528759009469
# length of actions is  583
# 159.4152633198744
# length of actions is  445
# -15.826720047555284
# length of actions is  132
# -45.03860883728491
# length of actions is  422
# Your final reward is : 54.41
# torch.from_numpy(rewards) looks like  torch.Size([1627])
# 158.8953285416245
# length of actions is  223
# 169.64740264792334
# length of actions is  239
# 4.98979705096601
# length of actions is  1000
# -39.064694607381995
# length of actions is  191
# 232.9205297254684
# length of actions is  354
# Your final reward is : 105.48
# torch.from_numpy(rewards) looks like  torch.Size([2350])
# 143.69592857703398
# length of actions is  379
# 132.698755149474
# length of actions is  267
# 257.4209991957438
# length of actions is  385
# -61.57331903873951
# length of actions is  210
# 77.57672518968822
# length of actions is  1000
# Your final reward is : 109.96
# torch.from_numpy(rewards) looks like  torch.Size([3514])
# 176.37329324708418
# length of actions is  205
# 213.88117380596958
# length of actions is  246
# -34.633502331641495
# length of actions is  100
# -52.6590044723555
# length of actions is  85
# 180.93666772652966
# length of actions is  255
# Your final reward is : 96.78
# torch.from_numpy(rewards) looks like  torch.Size([2504])
# 177.73153504735586
# length of actions is  204
# 257.27875600512516
# length of actions is  336
# 154.32924639079746
# length of actions is  702
# 244.86579895589296
# length of actions is  404
# 210.77609388689385
# length of actions is  431
# Your final reward is : 209.00
# torch.from_numpy(rewards) looks like  torch.Size([2731])
# 146.90114791826448
# length of actions is  322
# -58.74454942574037
# length of actions is  1000
# -65.84506910603213
# length of actions is  132
# 81.99361470885822
# length of actions is  880
# 168.55288047465478
# length of actions is  290
# Your final reward is : 54.57
# torch.from_numpy(rewards) looks like  torch.Size([2225])
# 158.7415367511893
# length of actions is  408
# -44.10223824772518
# length of actions is  81
# -84.86749829149582
# length of actions is  208
# 207.74808306298064
# length of actions is  340
# 146.50772167218474
# length of actions is  322
# Your final reward is : 76.81
# torch.from_numpy(rewards) looks like  torch.Size([2082])
# 184.03347906057652
# length of actions is  309
# 245.02036147189796
# length of actions is  368
# 105.18909104446521
# length of actions is  606
# 205.09420333927005
# length of actions is  498
# 157.1594718589438
# length of actions is  535
# Your final reward is : 179.30
# torch.from_numpy(rewards) looks like  torch.Size([2475])
# 165.57139052832633
# length of actions is  353
# 123.5522746955127
# length of actions is  571
# 189.39478886377884
# length of actions is  416
# 192.3881992177233
# length of actions is  387
# 157.30557504563743
# length of actions is  579
# Your final reward is : 165.64
# torch.from_numpy(rewards) looks like  torch.Size([2093])
# 165.33888538353145
# length of actions is  438
# -16.75153106617647
# length of actions is  326
# 112.50953314375394
# length of actions is  763
# 139.42354994307902
# length of actions is  607
# 204.0225096967693
# length of actions is  536
# Your final reward is : 120.91
# torch.from_numpy(rewards) looks like  torch.Size([2369])
# 188.09028680268787
# length of actions is  326
# 137.97287925714298
# length of actions is  761
# -11.559057625507766
# length of actions is  1000
# 121.2104635124936
# length of actions is  1000
# 159.80477194566834
# length of actions is  507
# Your final reward is : 119.10
# torch.from_numpy(rewards) looks like  torch.Size([2948])
# 148.7455415397212
# length of actions is  458
# 185.22604494351472
# length of actions is  411
# 152.35289512433656
# length of actions is  532
# 189.7226710410968
# length of actions is  459
# 206.6418197950627
# length of actions is  245
# Your final reward is : 176.54
# torch.from_numpy(rewards) looks like  torch.Size([3344])
# 138.16438668878993
# length of actions is  462
# 191.54740266771262
# length of actions is  529
# 90.10498895460242
# length of actions is  802
# 192.62934162125333
# length of actions is  393
# 181.75444745324592
# length of actions is  487
# Your final reward is : 158.84
# torch.from_numpy(rewards) looks like  torch.Size([2224])
# 22.16909119885899
# length of actions is  1000
# 136.25218769778309
# length of actions is  1000
# 121.19484188732001
# length of actions is  1000
# 143.5409585694908
# length of actions is  634
# 154.39175377921273
# length of actions is  990
# Your final reward is : 115.51
# torch.from_numpy(rewards) looks like  torch.Size([3462])
# 68.84779530778576
# length of actions is  1000
# 233.4325549842041
# length of actions is  398
# 220.51215440098164
# length of actions is  270
# 155.08244064238465
# length of actions is  454
# 90.31261152634657
# length of actions is  1000
# Your final reward is : 153.64
# torch.from_numpy(rewards) looks like  torch.Size([3064])
# 128.59624869222642
# length of actions is  775
# 238.80865431215906
# length of actions is  438
# 162.76218680475125
# length of actions is  740
# -22.814125237381234
# length of actions is  104
# 208.31762898541822
# length of actions is  570
# Your final reward is : 143.13
# torch.from_numpy(rewards) looks like  torch.Size([2850])
# 152.1556712540053
# length of actions is  400
# 211.0969933730819
# length of actions is  192
# 202.9445267448756
# length of actions is  593
# 126.01735589603445
# length of actions is  594
# 215.38972449342182
# length of actions is  261
# Your final reward is : 181.52
# torch.from_numpy(rewards) looks like  torch.Size([3426])
# 78.47439169732077
# length of actions is  1000
# 242.84183846208958
# length of actions is  394
# 220.06956090950246
# length of actions is  438
# 219.10100140356946
# length of actions is  385
# 68.99413484288108
# length of actions is  1000
# Your final reward is : 165.90
# torch.from_numpy(rewards) looks like  torch.Size([3013])
# 195.325799351754
# length of actions is  472
# 211.34424986860563
# length of actions is  358
# 215.18239515048845
# length of actions is  502
# 192.4053523802595
# length of actions is  474
# 245.31502824767006
# length of actions is  741
# Your final reward is : 211.91
# torch.from_numpy(rewards) looks like  torch.Size([2916])
# 162.01537698373107
# length of actions is  330
# 163.8903733457017
# length of actions is  1000
# 179.84843331617554
# length of actions is  385
# -33.73770537682337
# length of actions is  312
# 145.74678501367916
# length of actions is  651
# Your final reward is : 123.55
# torch.from_numpy(rewards) looks like  torch.Size([2400])
# -24.126989874381167
# length of actions is  299
# 198.80825012057147
# length of actions is  439
# 219.61948562757013
# length of actions is  367
# 81.59344145898119
# length of actions is  1000
# 236.19757779328125
# length of actions is  417
# Your final reward is : 142.42
# torch.from_numpy(rewards) looks like  torch.Size([2343])
# 71.58973877713575
# length of actions is  1000
# 83.9728683720881
# length of actions is  1000
# 224.41305362017317
# length of actions is  461
# 88.1460982069595
# length of actions is  709
# -42.91857592594208
# length of actions is  94
# Your final reward is : 85.04
# torch.from_numpy(rewards) looks like  torch.Size([2382])
# -31.730850617633763
# length of actions is  317
# 231.41289897877863
# length of actions is  261
# 113.97382666229832
# length of actions is  757
# 194.67807601554512
# length of actions is  433
# 214.40569482861025
# length of actions is  440
# Your final reward is : 144.55
# torch.from_numpy(rewards) looks like  torch.Size([2916])
# 161.74665371135563
# length of actions is  828
# 128.30066663778663
# length of actions is  758
# 73.62964233988119
# length of actions is  1000
# 78.88486915096122
# length of actions is  1000
# 218.12949394632153
# length of actions is  727
# Your final reward is : 132.14
# torch.from_numpy(rewards) looks like  torch.Size([3098])
# -25.775670300470864
# length of actions is  380
# 232.299055010813
# length of actions is  466
# 189.21506657225294
# length of actions is  471
# 56.491130931988835
# length of actions is  1000
# 200.07643085604178
# length of actions is  611
# Your final reward is : 130.46
# torch.from_numpy(rewards) looks like  torch.Size([1977])
# -37.23403289157484
# length of actions is  377
# 217.01752953678047
# length of actions is  423
# 188.4104676304557
# length of actions is  490
# 208.4928243971125
# length of actions is  483
# 223.7308882968681
# length of actions is  433
# Your final reward is : 160.08
# torch.from_numpy(rewards) looks like  torch.Size([2687])
# 161.27096353758213
# length of actions is  601
# 154.67881749122841
# length of actions is  742
# 213.26402638768553
# length of actions is  524
# 237.49687657118406
# length of actions is  445
# 206.18100632414794
# length of actions is  351
# Your final reward is : 194.58
# torch.from_numpy(rewards) looks like  torch.Size([2491])
# -70.67512064704313
# length of actions is  574
# 60.22668344245321
# length of actions is  1000
# 266.9795737750585
# length of actions is  442
# 206.17373468852628
# length of actions is  334
# 185.9040073201735
# length of actions is  511
# Your final reward is : 129.72
# torch.from_numpy(rewards) looks like  torch.Size([3136])
# 132.69963452361682
# length of actions is  704
# 248.53363631817874
# length of actions is  475
# 213.71949908168278
# length of actions is  400
# -86.84281261333643
# length of actions is  300
# 103.72635595099106
# length of actions is  872
# Your final reward is : 122.37
# torch.from_numpy(rewards) looks like  torch.Size([2948])
# -20.506044434849287
# length of actions is  420
# 119.33938456335312
# length of actions is  943
# 205.50888679318786
# length of actions is  522
# 247.60764967749893
# length of actions is  485
# 65.23324240166531
# length of actions is  1000
# Your final reward is : 123.44
# torch.from_numpy(rewards) looks like  torch.Size([2143])
# 81.20438576033699
# length of actions is  1000
# 253.97779117163296
# length of actions is  456
# 155.42770108530908
# length of actions is  804
# 224.76975397922817
# length of actions is  441
# 55.78909422273018
# length of actions is  1000
# Your final reward is : 154.23
# torch.from_numpy(rewards) looks like  torch.Size([2092])
# 185.21698992260752
# length of actions is  472
# 73.01324363911885
# length of actions is  1000
# 149.71662540912496
# length of actions is  592
# 156.2774415974508
# length of actions is  743
# 153.02867626378458
# length of actions is  711
# Your final reward is : 143.45
# torch.from_numpy(rewards) looks like  torch.Size([3046])
# 153.78527601011183
# length of actions is  514
# 224.5331033039705
# length of actions is  487
# 188.86704603702054
# length of actions is  386
# -72.50681177459786
# length of actions is  142
# 212.79740260796981
# length of actions is  510
# Your final reward is : 141.50
# torch.from_numpy(rewards) looks like  torch.Size([2867])
# 42.74326967002939
# length of actions is  1000
# 255.3053310504592
# length of actions is  407
# 164.51628776576882
# length of actions is  530
# 100.75130719881828
# length of actions is  864
# 179.44213280937538
# length of actions is  540
# Your final reward is : 148.55
# torch.from_numpy(rewards) looks like  torch.Size([2315])
# 184.5835040420341
# length of actions is  464
# 163.4507347313861
# length of actions is  840
# -0.26144221186717687
# length of actions is  153
# 79.39142430562774
# length of actions is  1000
# 132.70202342792584
# length of actions is  571
# Your final reward is : 111.97
# torch.from_numpy(rewards) looks like  torch.Size([2291])
# 155.12824655661558
# length of actions is  719
# 215.2482755075866
# length of actions is  529
# 182.50813759187673
# length of actions is  641
# 255.8429806384125
# length of actions is  501
# 154.5592307506682
# length of actions is  419
# Your final reward is : 192.66
# torch.from_numpy(rewards) looks like  torch.Size([1778])
# 165.20990555314847
# length of actions is  920
# 1.3361158585422004
# length of actions is  419
# -24.368385275573182
# length of actions is  1000
# 151.77058815165907
# length of actions is  649
# 232.99408116376839
# length of actions is  514
# Your final reward is : 105.39
# torch.from_numpy(rewards) looks like  torch.Size([3169])
# 151.44749700842115
# length of actions is  618
# 159.74519702099576
# length of actions is  558
# 151.17681962085257
# length of actions is  647
# 159.7017073851677
# length of actions is  587
# 240.70772750419783
# length of actions is  467
# Your final reward is : 172.56
# torch.from_numpy(rewards) looks like  torch.Size([3136])
# 156.4418645030185
# length of actions is  938
# 139.22434314453506
# length of actions is  1000
# 197.9903448070714
# length of actions is  412
# 176.46172938277357
# length of actions is  441
# 168.92766583499503
# length of actions is  487
# Your final reward is : 167.81
# torch.from_numpy(rewards) looks like  torch.Size([2919])
# 161.10167228065765
# length of actions is  612
# -27.9766526123884
# length of actions is  1000
# 205.13330017947294
# length of actions is  708
# -57.59913006482819
# length of actions is  395
# 174.21202635286687
# length of actions is  830
# Your final reward is : 90.97
# torch.from_numpy(rewards) looks like  torch.Size([1768])
# -59.40331355477548
# length of actions is  338
# -35.73270378475243
# length of actions is  447
# 24.26154287739728
# length of actions is  1000
# 107.17193431096328
# length of actions is  955
# 176.34383418137097
# length of actions is  463
# Your final reward is : 42.53
# torch.from_numpy(rewards) looks like  torch.Size([2660])
# 160.26226089533708
# length of actions is  582
# 63.687600340330505
# length of actions is  1000
# 76.10294382371097
# length of actions is  1000
# 196.30812412306932
# length of actions is  442
# 125.76393702645856
# length of actions is  594
# Your final reward is : 124.42
# torch.from_numpy(rewards) looks like  torch.Size([3205])
# -78.27183631907556
# length of actions is  225
# 182.20124729160935
# length of actions is  401
# -27.46314897010234
# length of actions is  369
# 166.70503301938686
# length of actions is  383
# 185.17240757916193
# length of actions is  485
# Your final reward is : 85.67
# torch.from_numpy(rewards) looks like  torch.Size([2600])
# -33.291166445705
# length of actions is  216
# 223.32769247198073
# length of actions is  376
# 247.00310233678758
# length of actions is  557
# -7.465563035025426
# length of actions is  311
# -18.72021150278495
# length of actions is  243
# Your final reward is : 82.17
# torch.from_numpy(rewards) looks like  torch.Size([2042])
# -76.88113714318017
# length of actions is  219
# 230.2647028914158
# length of actions is  615
# 11.177435241310548
# length of actions is  347
# 169.64078755123444
# length of actions is  471
# 186.380129550054
# length of actions is  456
# Your final reward is : 104.12
# torch.from_numpy(rewards) looks like  torch.Size([2548])
# -60.1279275099523
# length of actions is  216
# 221.43824939421356
# length of actions is  375
# 233.22089159392883
# length of actions is  435
# 57.68670522201009
# length of actions is  305
# 183.03864676098144
# length of actions is  539
# Your final reward is : 127.05
# torch.from_numpy(rewards) looks like  torch.Size([2452])
# -77.63723753789421
# length of actions is  242
# 239.88616662127103
# length of actions is  506
# 192.3060406611453
# length of actions is  536
# 161.53335319756778
# length of actions is  609
# 259.21258593784796
# length of actions is  389
# Your final reward is : 155.06
# torch.from_numpy(rewards) looks like  torch.Size([3145])
# -58.809449829687416
# length of actions is  225
# 216.0491011184787
# length of actions is  823
# 182.40832722890394
# length of actions is  488
# 269.62511963218026
# length of actions is  390
# 249.0304486805408
# length of actions is  506
# Your final reward is : 171.66
# torch.from_numpy(rewards) looks like  torch.Size([2450])
# 92.9027219180388
# length of actions is  1000
# 263.1517785119587
# length of actions is  369
# 269.41216056325004
# length of actions is  348
# 170.34896551920332
# length of actions is  647
# -14.623016752865112
# length of actions is  291
# Your final reward is : 156.24
# torch.from_numpy(rewards) looks like  torch.Size([2816])
# 137.90558543179085
# length of actions is  397
# 245.95866520647644
# length of actions is  428
# 185.26548481050858
# length of actions is  433
# 160.88346435987094
# length of actions is  503
# -108.3908453820665
# length of actions is  451
# Your final reward is : 124.32
# torch.from_numpy(rewards) looks like  torch.Size([2197])
# -67.64657426465237
# length of actions is  342
# 92.36822926917021
# length of actions is  686
# 95.30703149719528
# length of actions is  905
# 129.67760329736174
# length of actions is  542
# 144.44022218984202
# length of actions is  572
# Your final reward is : 78.83
# torch.from_numpy(rewards) looks like  torch.Size([2539])
# -78.29866090945166
# length of actions is  351
# -24.0317785502428
# length of actions is  1000
# -68.46654308863909
# length of actions is  1000
# 174.2889389380293
# length of actions is  931
# 105.71983127788424
# length of actions is  520
# Your final reward is : 21.84
# torch.from_numpy(rewards) looks like  torch.Size([3985])
# 72.12641718457282
# length of actions is  1000
# 265.5196502927265
# length of actions is  385
# -43.63526981803608
# length of actions is  1000
# -39.88896921182042
# length of actions is  1000
# -59.34924471007453
# length of actions is  1000
# Your final reward is : 38.95
# torch.from_numpy(rewards) looks like  torch.Size([2080])
# 40.93374578176834
# length of actions is  1000
# 264.7559990267699
# length of actions is  306
# 278.25311706465067
# length of actions is  291
# 122.83868141331149
# length of actions is  570
# 243.15659688389675
# length of actions is  384
# Your final reward is : 189.99
# torch.from_numpy(rewards) looks like  torch.Size([2882])
# -39.52897254624013
# length of actions is  1000
# 272.47713311082157
# length of actions is  327
# 183.6263293376968
# length of actions is  406
# 210.52059535266812
# length of actions is  410
# 171.0327617016599
# length of actions is  401
# Your final reward is : 159.63
# torch.from_numpy(rewards) looks like  torch.Size([3082])
# 130.04332876574668
# length of actions is  775
# 87.75929980379227
# length of actions is  1000
# 275.0769949651983
# length of actions is  310
# -33.72568191269
# length of actions is  1000
# 233.5888568131905
# length of actions is  366
# Your final reward is : 138.55
# torch.from_numpy(rewards) looks like  torch.Size([3136])
# -48.2593327694362
# length of actions is  1000
# 266.8337832509609
# length of actions is  306
# 276.7729766587909
# length of actions is  304
# -2.86188466149064
# length of actions is  1000
# 157.85306745909838
# length of actions is  1000
# Your final reward is : 130.07
# torch.from_numpy(rewards) looks like  torch.Size([2974])
# 59.28434154194962
# length of actions is  1000
# 265.36364035832094
# length of actions is  300
# 76.9508505178421
# length of actions is  1000
# 182.4745177395416
# length of actions is  333
# 189.72422982715648
# length of actions is  414
# Your final reward is : 154.76
# torch.from_numpy(rewards) looks like  torch.Size([2415])
# -16.612530394824873
# length of actions is  1000
# 148.49557777863464
# length of actions is  1000
# 267.6552093473823
# length of actions is  284
# 200.54258268622294
# length of actions is  728
# 251.19429430757071
# length of actions is  360
# Your final reward is : 170.26
# torch.from_numpy(rewards) looks like  torch.Size([3432])
# 38.91866381758453
# length of actions is  1000
# 154.77727265772972
# length of actions is  1000
# 263.06400974307644
# length of actions is  293
# -25.185444557388365
# length of actions is  1000
# 170.48211047138824
# length of actions is  505
# Your final reward is : 120.41
# torch.from_numpy(rewards) looks like  torch.Size([2319])
# 42.54788593960114
# length of actions is  1000
# 146.2139385636291
# length of actions is  1000
# 265.857825332257
# length of actions is  278
# 231.26770741997498
# length of actions is  549
# 179.57881782702293
# length of actions is  353
# Your final reward is : 173.09
# torch.from_numpy(rewards) looks like  torch.Size([2694])
# 190.82114314425849
# length of actions is  787
# 125.19255273890398
# length of actions is  1000
# -42.43649797420201
# length of actions is  1000
# 46.28538212849537
# length of actions is  1000
# 209.94375753847066
# length of actions is  410
# Your final reward is : 105.96
# torch.from_numpy(rewards) looks like  torch.Size([2919])
# 188.97147336989224
# length of actions is  444
# 214.5627589449188
# length of actions is  371
# 44.60370925496098
# length of actions is  1000
# 242.81427527077338
# length of actions is  332
# 24.104257218314263
# length of actions is  1000
# Your final reward is : 143.01
# torch.from_numpy(rewards) looks like  torch.Size([2320])
# 46.63398481948477
# length of actions is  1000
# 278.9621320921203
# length of actions is  261
# 217.43759684444342
# length of actions is  295
# 266.32813479823614
# length of actions is  316
# 266.0549314606628
# length of actions is  279
# Your final reward is : 215.08
# torch.from_numpy(rewards) looks like  torch.Size([2275])
# -25.5851661240701
# length of actions is  488
# 108.02257922574282
# length of actions is  1000
# 264.3633355215443
# length of actions is  257
# 243.84564352636616
# length of actions is  754
# 273.91173939547537
# length of actions is  251
# Your final reward is : 172.91
# torch.from_numpy(rewards) looks like  torch.Size([3217])
# 151.62182881154826
# length of actions is  600
# 270.1776661896779
# length of actions is  239
# 190.48745375756877
# length of actions is  614
# 237.38238842633606
# length of actions is  308
# 81.69269223744791
# length of actions is  1000
# Your final reward is : 186.27
# torch.from_numpy(rewards) looks like  torch.Size([4275])
# 170.98432029911885
# length of actions is  534
# 268.48480351812424
# length of actions is  293
# 35.041344571174676
# length of actions is  1000
# 147.15208813447424
# length of actions is  761
# 223.3523157306674
# length of actions is  329
# Your final reward is : 169.00
# torch.from_numpy(rewards) looks like  torch.Size([1623])
# 172.62684488189404
# length of actions is  535
# 207.9426046936755
# length of actions is  412
# 232.4238822691136
# length of actions is  265
# 232.28118901514893
# length of actions is  325
# 208.82586537779696
# length of actions is  440
# Your final reward is : 210.82
# torch.from_numpy(rewards) looks like  torch.Size([1759])
# 174.74246195316346
# length of actions is  452
# 262.9594638005724
# length of actions is  293
# 197.33194059472214
# length of actions is  701
# 195.94973271410635
# length of actions is  415
# 240.827795398033
# length of actions is  290
# Your final reward is : 214.36
# torch.from_numpy(rewards) looks like  torch.Size([1724])
# 188.58899675982317
# length of actions is  985
# 89.49550870049019
# length of actions is  1000
# 227.689071868012
# length of actions is  301
# 125.66315895723318
# length of actions is  1000
# 118.07290232148215
# length of actions is  1000
# Your final reward is : 149.90
# torch.from_numpy(rewards) looks like  torch.Size([1812])
# 202.18185581082875
# length of actions is  868
# 209.30005310957088
# length of actions is  527
# 224.25832800817784
# length of actions is  293
# 259.43234151341915
# length of actions is  333
# 207.7588709926198
# length of actions is  302
# Your final reward is : 220.59
# torch.from_numpy(rewards) looks like  torch.Size([2432])
# 202.77083486213232
# length of actions is  752
# -2.4386846033856244
# length of actions is  448
# 215.1482135824342
# length of actions is  328
# 108.4871525468873
# length of actions is  1000
# 162.2994557371342
# length of actions is  522
# Your final reward is : 137.25
# torch.from_numpy(rewards) looks like  torch.Size([1736])
# 180.79981431939567
# length of actions is  506
# 259.74249410365326
# length of actions is  271
# 189.33948136083453
# length of actions is  464
# 237.8091552348106
# length of actions is  298
# 224.37746600399623
# length of actions is  308
# Your final reward is : 218.41
# torch.from_numpy(rewards) looks like  torch.Size([2148])
# 202.44566794211374
# length of actions is  311
# 239.61196240798807
# length of actions is  250
# 261.59734876031195
# length of actions is  242
# 252.6915159898077
# length of actions is  264
# 240.85495058418218
# length of actions is  373
# Your final reward is : 239.44
# torch.from_numpy(rewards) looks like  torch.Size([2456])
# 190.28435460588557
# length of actions is  790
# 181.99123522271722
# length of actions is  642
# 230.9213940937276
# length of actions is  321
# 209.82100848698298
# length of actions is  339
# 241.44431270197552
# length of actions is  250
# Your final reward is : 210.89
# torch.from_numpy(rewards) looks like  torch.Size([1738])
# 187.419822101369
# length of actions is  787
# 121.27225767373538
# length of actions is  1000
# 90.63027846656443
# length of actions is  1000
# 215.878478045544
# length of actions is  466
# 196.5366217842336
# length of actions is  279
# Your final reward is : 162.35
# torch.from_numpy(rewards) looks like  torch.Size([2181])
# 101.12128611335581
# length of actions is  1000
# 241.04821370037567
# length of actions is  272
# 120.24099790947204
# length of actions is  1000
# 159.06454977748967
# length of actions is  556
# 253.7203623450591
# length of actions is  261
# Your final reward is : 175.04
# torch.from_numpy(rewards) looks like  torch.Size([1999])
# 194.76746284532956
# length of actions is  376
# 205.85369642540377
# length of actions is  317
# 214.55917471495167
# length of actions is  486
# 190.5041556856152
# length of actions is  463
# 186.4092734407397
# length of actions is  379
# Your final reward is : 198.42
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 100.637139880814
# length of actions is  1000
# 210.75142832769623
# length of actions is  315
# 197.80839769506363
# length of actions is  345
# 214.99167127676222
# length of actions is  457
# 84.56525583227096
# length of actions is  1000
# Your final reward is : 161.75
# torch.from_numpy(rewards) looks like  torch.Size([2603])
# 52.13270539752084
# length of actions is  1000
# 215.4698496500433
# length of actions is  279
# 219.57762038038925
# length of actions is  271
# 215.85497899424132
# length of actions is  312
# -41.97638214192936
# length of actions is  205
# Your final reward is : 132.21
# torch.from_numpy(rewards) looks like  torch.Size([2918])
# 160.51373744699674
# length of actions is  609
# 83.02470792052219
# length of actions is  1000
# 215.91212379632879
# length of actions is  470
# 257.81413951545505
# length of actions is  306
# 160.37504683430603
# length of actions is  513
# Your final reward is : 175.53
# torch.from_numpy(rewards) looks like  torch.Size([2434])
# 50.48040058519758
# length of actions is  1000
# 217.6390936493843
# length of actions is  311
# 215.12130216840723
# length of actions is  275
# 66.44871326937582
# length of actions is  1000
# 219.14731373591067
# length of actions is  275
# Your final reward is : 153.77
# torch.from_numpy(rewards) looks like  torch.Size([2659])
# 203.81365142525442
# length of actions is  376
# 212.3118660974481
# length of actions is  257
# 190.66240822165696
# length of actions is  388
# 199.70899893845078
# length of actions is  471
# 180.7695922767785
# length of actions is  569
# Your final reward is : 197.45
# torch.from_numpy(rewards) looks like  torch.Size([2324])
# 201.48271966293532
# length of actions is  352
# 262.2135131256524
# length of actions is  218
# 266.73020381812046
# length of actions is  232
# -15.541214129883699
# length of actions is  471
# 182.22799255214272
# length of actions is  359
# Your final reward is : 179.42
# torch.from_numpy(rewards) looks like  torch.Size([2422])
# 169.6913011068753
# length of actions is  556
# 43.22991627456057
# length of actions is  1000
# 224.22485243853768
# length of actions is  254
# 263.6728864240898
# length of actions is  244
# 235.76107314312748
# length of actions is  261
# Your final reward is : 187.32
# torch.from_numpy(rewards) looks like  torch.Size([1896])
# 197.78554361332883
# length of actions is  580
# 108.88416028488979
# length of actions is  1000
# 217.15599153976652
# length of actions is  288
# 192.34605355835492
# length of actions is  485
# 86.51700784073172
# length of actions is  1000
# Your final reward is : 160.54
# torch.from_numpy(rewards) looks like  torch.Size([3868])
# 95.39055484869397
# length of actions is  1000
# 228.9162822383619
# length of actions is  522
# 197.81768454752802
# length of actions is  348
# -24.62225838223179
# length of actions is  218
# 175.37244243015513
# length of actions is  397
# Your final reward is : 134.57
# torch.from_numpy(rewards) looks like  torch.Size([3600])
# 152.3735492915598
# length of actions is  604
# 187.33844680453464
# length of actions is  483
# 168.450797477754
# length of actions is  611
# 203.73449630936312
# length of actions is  274
# 231.7435060698454
# length of actions is  304
# Your final reward is : 188.73
# torch.from_numpy(rewards) looks like  torch.Size([3974])
# 188.10016738322645
# length of actions is  418
# -39.95583595592138
# length of actions is  1000
# 239.41227149180565
# length of actions is  619
# 212.6622878343125
# length of actions is  421
# 230.42712686595326
# length of actions is  355
# Your final reward is : 166.13
# torch.from_numpy(rewards) looks like  torch.Size([2836])
# 191.75331601835774
# length of actions is  413
# 244.10402759682955
# length of actions is  250
# 231.04692458235854
# length of actions is  380
# 220.6979282564609
# length of actions is  283
# 227.82870595578368
# length of actions is  308
# Your final reward is : 223.09
# torch.from_numpy(rewards) looks like  torch.Size([2963])
# 197.89171525802726
# length of actions is  370
# 231.26180796580348
# length of actions is  290
# 190.49270089004946
# length of actions is  431
# 216.12726695504438
# length of actions is  281
# 219.34852869096537
# length of actions is  307
# Your final reward is : 211.02
# torch.from_numpy(rewards) looks like  torch.Size([2977])
# 187.26138697434277
# length of actions is  678
# -23.231538072298463
# length of actions is  302
# 177.26946772971064
# length of actions is  356
# 224.29381850589925
# length of actions is  251
# 228.06802111790614
# ...
# 239.75287407233134
# length of actions is  413
# -24.488488234260288
# length of actions is  176
# Your final reward is : 193.69
# torch.from_numpy(rewards) looks like  torch.Size([2600])
# 233.69796527950402
# length of actions is  405
# 243.31646146932306
# length of actions is  311
# 13.33628101063782
# length of actions is  187
# 231.99343012711196
# length of actions is  384
# 223.55141360645024
# length of actions is  367
# Your final reward is : 189.18
# torch.from_numpy(rewards) looks like  torch.Size([1989])
# 244.82860956605313
# length of actions is  356
# 166.52381921722508
# length of actions is  735
# 233.95275584950116
# length of actions is  350
# 221.4689317966143
# length of actions is  333
# 4.660468447282696
# length of actions is  225
# Your final reward is : 174.29
# torch.from_numpy(rewards) looks like  torch.Size([3974])
# 230.38651724255175
# length of actions is  415
# 199.6561152126347
# length of actions is  404
# 207.67366923339193
# length of actions is  367
# -6.808686768442641
# length of actions is  125
# 219.20394293304423
# length of actions is  331
# Your final reward is : 170.02
# torch.from_numpy(rewards) looks like  torch.Size([2238])
# 234.9705448335167
# length of actions is  407
# -38.78459216185186
# length of actions is  149
# 229.38312191486355
# length of actions is  373
# 207.9307340708864
# length of actions is  318
# -9.39038710094517
# length of actions is  1000
# Your final reward is : 124.82
# torch.from_numpy(rewards) looks like  torch.Size([2417])
# 247.72553726279287
# length of actions is  350
# 228.7430006786023
# length of actions is  377
# 221.6148630386246
# length of actions is  447
# 201.12602020045153
# length of actions is  393
# 221.6651563233886
# length of actions is  376
# Your final reward is : 224.17
# torch.from_numpy(rewards) looks like  torch.Size([1992])
# 118.52633819459348
# length of actions is  1000
# -5.607997635551778
# length of actions is  1000
# 136.82943693981147
# length of actions is  1000
# 100.33606639717301
# length of actions is  1000
# 97.32747208952999
# length of actions is  1000
# Your final reward is : 89.48
# torch.from_numpy(rewards) looks like  torch.Size([2300])
# 227.8806052313303
# length of actions is  421
# 213.1797389546931
# length of actions is  430
# 221.99061671831697
# length of actions is  415
# 225.63147416621473
# length of actions is  434
# 310.42962940252175
# length of actions is  260
# Your final reward is : 239.82
# torch.from_numpy(rewards) looks like  torch.Size([3401])
# 212.53183572573388
# length of actions is  506
# 212.10035086855447
# length of actions is  527
# -5.010408555447228
# length of actions is  164
# 274.361251091232
# length of actions is  366
# 213.23256226510398
# length of actions is  475
# Your final reward is : 181.44
# torch.from_numpy(rewards) looks like  torch.Size([1852])
# 216.37214824655993
# length of actions is  493
# 275.4794250438366
# length of actions is  324
# 219.37447076293725
# length of actions is  453
# 228.5007561014204
# length of actions is  433
# 218.84246909143667
# length of actions is  440
# Your final reward is : 231.71
# torch.from_numpy(rewards) looks like  torch.Size([2277])
# 236.70983371091228
# length of actions is  423
# -15.558120990380722
# length of actions is  1000
# 8.040183348076177
# length of actions is  1000
# 219.0834181930757
# length of actions is  472
# 250.40029256648845
# length of actions is  267
# Your final reward is : 139.74
# torch.from_numpy(rewards) looks like  torch.Size([2275])
# 248.2105546575598
# length of actions is  335
# 221.80841574772052
# length of actions is  389
# 253.3715691627718
# length of actions is  291
# 234.25435371410092
# length of actions is  511
# 274.6305399926676
# length of actions is  844
# Your final reward is : 246.46
# torch.from_numpy(rewards) looks like  torch.Size([2112])
# 223.21587643035656
# length of actions is  487
# 213.2241389890663
# length of actions is  555
# 230.33149833573208
# length of actions is  458
# 186.9464886685073
# length of actions is  768
# 262.3338467951005
# length of actions is  465
# Your final reward is : 223.21
# torch.from_numpy(rewards) looks like  torch.Size([2688])
# 229.66479952096853
# length of actions is  463
# 189.86775121185227
# length of actions is  705
# 175.20184457155767
# length of actions is  641
# 213.59470020692146
# length of actions is  485
# 207.6408858595081
# length of actions is  594
# Your final reward is : 203.19
# torch.from_numpy(rewards) looks like  torch.Size([2412])
# 245.88919726200888
# length of actions is  354
# -7.364820249041635
# length of actions is  1000
# 230.9112724802483
# length of actions is  417
# 244.07129910459247
# length of actions is  442
# 244.43297233849626
# length of actions is  463
# Your final reward is : 191.59
# torch.from_numpy(rewards) looks like  torch.Size([2729])
# 232.73771481373257
# length of actions is  420
# -11.737371113639085
# length of actions is  172
# 247.33641492252343
# length of actions is  424
# 183.52825590702633
# length of actions is  464
# 225.8703927381971
# length of actions is  425
# Your final reward is : 175.55
# torch.from_numpy(rewards) looks like  torch.Size([2867])
# 227.82293124973182
# length of actions is  441
# 192.11533239655773
# length of actions is  645
# -4.677133528597598
# length of actions is  1000
# 250.61417416397785
# length of actions is  480
# 251.01583665448493
# length of actions is  335
# Your final reward is : 183.38
# torch.from_numpy(rewards) looks like  torch.Size([2082])
# 252.10149778240628
# length of actions is  342
# -26.513530486093117
# length of actions is  129
# 274.5302966822027
# length of actions is  371
# 247.46057914858355
# length of actions is  473
# 249.422996647967
# length of actions is  466
# Your final reward is : 199.40
# torch.from_numpy(rewards) looks like  torch.Size([2000])
# 250.44146016650376
# length of actions is  344
# 128.56648202630734
# length of actions is  1000
# 126.94748702019128
# length of actions is  1000
# 219.86105251660314
# length of actions is  465
# -4.129703710049293
# length of actions is  1000
# Your final reward is : 144.34
# torch.from_numpy(rewards) looks like  torch.Size([2277])
# 231.8661939105661
# length of actions is  410
# 230.22127468964
# length of actions is  513
# 226.496282463979
# length of actions is  355
# 250.8714720200664
# length of actions is  248
# -12.348405485314863
# length of actions is  1000
# Your final reward is : 185.42
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 250.6055608165748
# length of actions is  321
# 236.42737886290777
# length of actions is  368
# 6.178111310812682
# length of actions is  1000
# 159.08332790764655
# length of actions is  646
# 206.27032572176256
# length of actions is  615
# Your final reward is : 171.71
# torch.from_numpy(rewards) looks like  torch.Size([3083])
# 248.391477878503
# length of actions is  325
# 184.82381798997235
# length of actions is  511
# 214.12222259026746
# length of actions is  389
# 199.30170887087246
# length of actions is  640
# 237.65391316475277
# length of actions is  413
# Your final reward is : 216.86
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 250.48192439273953
# length of actions is  330
# -21.329453843118586
# length of actions is  1000
# 235.54269611732437
# length of actions is  563
# 216.51843307251477
# length of actions is  346
# 211.7678051176738
# length of actions is  555
# Your final reward is : 178.60
# torch.from_numpy(rewards) looks like  torch.Size([1814])
# 253.59121308383453
# length of actions is  311
# 112.91221394614274
# length of actions is  1000
# 202.56780240818088
# length of actions is  541
# 246.37768179058443
# length of actions is  249
# 214.82867317761557
# length of actions is  365
# Your final reward is : 206.06
# torch.from_numpy(rewards) looks like  torch.Size([3080])
# 267.2278246631836
# length of actions is  233
# 220.41258669801326
# length of actions is  544
# -18.42363152323335
# length of actions is  1000
# 113.38615266035835
# length of actions is  1000
# 241.55610890024312
# length of actions is  410
# Your final reward is : 164.83
# torch.from_numpy(rewards) looks like  torch.Size([2228])
# 249.75077289902487
# length of actions is  319
# 230.99566406031522
# length of actions is  348
# -9.308542150867522
# length of actions is  1000
# -9.303524570494538
# length of actions is  1000
# -24.53690573013145
# length of actions is  1000
# Your final reward is : 87.52
# torch.from_numpy(rewards) looks like  torch.Size([2097])
# 249.92409562233766
# length of actions is  340
# 21.25163198660492
# length of actions is  1000
# 231.1656676955157
# length of actions is  516
# 259.89717101499656
# length of actions is  395
# -4.657176535270268
# length of actions is  1000
# Your final reward is : 151.52
# torch.from_numpy(rewards) looks like  torch.Size([2917])
# 246.6974886705937
# length of actions is  345
# 193.82592069789837
# length of actions is  407
# 220.59432946383643
# length of actions is  498
# 175.81526049699482
# length of actions is  607
# 215.75446741014827
# length of actions is  542
# Your final reward is : 210.54
# torch.from_numpy(rewards) looks like  torch.Size([1971])
# 250.99690652134288
# length of actions is  316
# 210.49459825077267
# length of actions is  401
# 226.94858018005132
# length of actions is  529
# 201.53923740861626
# length of actions is  580
# 275.910297156724
# length of actions is  404
# Your final reward is : 233.18
# torch.from_numpy(rewards) looks like  torch.Size([1736])
# 254.5549407731945
# length of actions is  325
# 82.39391671264957
# length of actions is  1000
# 201.42975351050967
# length of actions is  524
# 237.45782319338923
# length of actions is  348
# 233.69044656527788
# length of actions is  405
# Your final reward is : 201.91
# torch.from_numpy(rewards) looks like  torch.Size([1849])
# 256.36586491699313
# length of actions is  316
# 224.2706504218059
# length of actions is  333
# -7.857558694680793
# length of actions is  1000
# 262.91068067891786
# length of actions is  320
# 240.05692623492308
# length of actions is  262
# Your final reward is : 195.15
# torch.from_numpy(rewards) looks like  torch.Size([1507])
# 261.3820461701143
# length of actions is  257
# 167.7785217445461
# length of actions is  1000
# 241.50701110435025
# length of actions is  253
# 295.72969612257407
# length of actions is  203
# 5.868687248744394
# length of actions is  1000
# Your final reward is : 194.45
# torch.from_numpy(rewards) looks like  torch.Size([2235])
# 252.84902628958756
# length of actions is  305
# 15.819906105649693
# length of actions is  1000
# 210.00804593418093
# length of actions is  555
# 223.31943675478828
# length of actions is  491
# 252.8828822503628
# length of actions is  338
# Your final reward is : 190.98
# torch.from_numpy(rewards) looks like  torch.Size([2121])
# 137.16733881826897
# length of actions is  1000
# 2.929466529165966
# length of actions is  1000
# 248.43625363343028
# length of actions is  365
# 254.0401054748002
# length of actions is  265
# 51.01919413213338
# length of actions is  129
# Your final reward is : 138.72
# torch.from_numpy(rewards) looks like  torch.Size([2987])
# 274.09981901763365
# length of actions is  203
# 225.82191026979467
# length of actions is  212
# 3.4436368514898827
# length of actions is  1000
# 18.696493337719847
# length of actions is  1000
# 212.64773791634772
# length of actions is  451
# Your final reward is : 146.94
# torch.from_numpy(rewards) looks like  torch.Size([1317])
# 253.3811285539811
# length of actions is  279
# 264.14302282888053
# length of actions is  291
# 281.95137817815043
# length of actions is  173
# 211.32973136325108
# length of actions is  499
# 203.81249530239396
# length of actions is  454
# Your final reward is : 242.92
# torch.from_numpy(rewards) looks like  torch.Size([2276])
# 249.93804871331017
# length of actions is  286
# 253.14791682931315
# length of actions is  285
# 253.7240464233945
# length of actions is  407
# 260.9404196639378
# length of actions is  386
# 245.04634034677503
# length of actions is  379
# Your final reward is : 252.56
# torch.from_numpy(rewards) looks like  torch.Size([2350])
# 257.31475803932426
# length of actions is  268
# 202.09254054092742
# length of actions is  442
# 230.48635805308575
# length of actions is  418
# 208.84909078851211
# length of actions is  379
# 233.4268875572676
# length of actions is  332
# Your final reward is : 226.43
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 41.18957665760925
# length of actions is  135
# 280.65243658961725
# length of actions is  158
# 259.8821573235476
# length of actions is  363
# 195.2175564872913
# length of actions is  675
# 274.0469414083674
# length of actions is  236
# Your final reward is : 210.20
# torch.from_numpy(rewards) looks like  torch.Size([2163])
# 265.34116561592623
# length of actions is  183
# 259.797724579841
# length of actions is  328
# 281.54913065736145
# length of actions is  539
# 217.2590587430825
# length of actions is  450
# 259.3301786083618
# length of actions is  254
# Your final reward is : 256.66
# torch.from_numpy(rewards) looks like  torch.Size([1589])
# 258.3250990898457
# length of actions is  232
# 260.83972173353095
# length of actions is  284
# 243.4348670868265
# length of actions is  363
# 255.60276510511008
# length of actions is  164
# 248.2494821502394
# length of actions is  428
# Your final reward is : 253.29
# torch.from_numpy(rewards) looks like  torch.Size([1348])
# 254.6225483804521
# length of actions is  241
# 243.62148139027295
# length of actions is  274
# 253.9666513565426
# length of actions is  369
# 249.13210236481336
# length of actions is  271
# 238.5440122722147
# length of actions is  258
# Your final reward is : 247.98
# torch.from_numpy(rewards) looks like  torch.Size([1422])
# 245.9075903405894
# length of actions is  291
# 267.37694097129076
# length of actions is  299
# 262.1084611111026
# length of actions is  331
# 290.0929812414229
# length of actions is  315
# 250.67885795381164
# length of actions is  389
# Your final reward is : 263.23
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 254.12880339592053
# length of actions is  238
# 216.89393637703498
# length of actions is  340
# 234.63678070547243
# length of actions is  328
# 258.76345313187005
# length of actions is  272
# 1.79845487079524
# length of actions is  94
# Your final reward is : 193.24
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 241.8226489219367
# length of actions is  276
# 263.5798551745986
# length of actions is  317
# 135.36443614792373
# length of actions is  1000
# 245.14148794641758
# length of actions is  400
# 229.74385349392503
# length of actions is  301
# Your final reward is : 223.13
# torch.from_numpy(rewards) looks like  torch.Size([1963])
# 248.47512784101383
# length of actions is  251
# 236.8139886861174
# length of actions is  314
# 194.9126664147579
# length of actions is  773
# 241.5643848345937
# length of actions is  234
# 235.33901202042034
# length of actions is  442
# Your final reward is : 231.42
# torch.from_numpy(rewards) looks like  torch.Size([1541])
# 238.5602595187455
# length of actions is  302
# 222.0968786300274
# length of actions is  241
# 276.34087630986966
# length of actions is  224
# 256.0823609987509
# length of actions is  389
# 146.75594258096154
# length of actions is  1000
# Your final reward is : 227.97
# torch.from_numpy(rewards) looks like  torch.Size([1348])
# 250.42226853083045
# length of actions is  250
# 223.15424728910514
# length of actions is  354
# 49.65406072977157
# length of actions is  139
# 236.96185336771612
# length of actions is  354
# 263.25853991689144
# length of actions is  232
# Your final reward is : 204.69
# torch.from_numpy(rewards) looks like  torch.Size([2719])
# 117.00173940816244
# length of actions is  1000
# -26.029327787073825
# length of actions is  1000
# 273.33799299820794
# length of actions is  285
# -15.929064124586551
# length of actions is  1000
# 256.1611691302933
# length of actions is  403
# Your final reward is : 120.91
# torch.from_numpy(rewards) looks like  torch.Size([949])
# 135.61094868357
# length of actions is  1000
# 10.224287821184891
# length of actions is  1000
# 267.51611122607545
# length of actions is  277
# 174.4112876588952
# length of actions is  1000
# 273.1017776240292
# length of actions is  232
# Your final reward is : 172.17
# torch.from_numpy(rewards) looks like  torch.Size([2282])
# 255.30065563779925
# length of actions is  234
# 254.26181394396872
# length of actions is  263
# 142.41097250622025
# length of actions is  1000
# 276.5853951280748
# length of actions is  191
# 235.86093656891376
# length of actions is  243
# Your final reward is : 232.88
# torch.from_numpy(rewards) looks like  torch.Size([2046])
# 253.1788090604336
# length of actions is  260
# 235.46784441453767
# length of actions is  182
# 238.22468542533773
# length of actions is  553
# 242.56333110548542
# length of actions is  328
# 268.056176839458
# length of actions is  260
# Your final reward is : 247.50

# %% [markdown]
# ### 訓練結果
#
# 訓練過程中，我們持續記下了 `avg_total_reward`，這個數值代表的是：每次更新 policy network 前，我們讓 agent 玩數個回合（episodes），而這些回合的平均 total rewards 為何。
# 理論上，若是 agent 一直在進步，則所得到的 `avg_total_reward` 也會持續上升，直至 250 上下。
# 若將其畫出來則結果如下：

# %%
end = time.time()
plt.plot(avg_total_rewards)
plt.title("Total Rewards")
plt.show()

# %% [markdown]
# 另外，`avg_final_reward` 代表的是多個回合的平均 final rewards，而 final reward 即是 agent 在單一回合中拿到的最後一個 reward。
# 如果同學們還記得環境給予登月小艇 reward 的方式，便會知道，不論**回合的最後**小艇是不幸墜毀、飛出畫面、或是靜止在地面上，都會受到額外地獎勵或處罰。
# 也因此，final reward 可被用來觀察 agent 的「著地」是否順利等資訊。

# %%
plt.plot(avg_final_rewards)
plt.title("Final Rewards")
plt.show()

# %% [markdown]
# 訓練時間

# %%
print(f"total time is {end-start} sec")
# Out:
# total time is 4513.703870773315 sec

# %%
best_batch
# Out:
# 416

# %% [markdown]
# # Server 測試
# 到時候下面會是我們Server上測試的環境，可以給大家看一下自己的表現如何

# %%
PATH = "Action_List_test" + str(best_batch) + ".npy"
action_list = np.load(PATH,allow_pickle=True) #到時候你上傳的檔案
seed = 543 #到時候測試的seed 請不要更改
fix(env, seed)

#agent.network.eval()  # 測試前先將 network 切換為 evaluation 模式

test_total_reward = []
for actions in action_list:
    state = env.reset()
    img = plt.imshow(env.render(mode='rgb_array'))

    total_reward = 0

    done = False
    # while not done:
    done_count = 0
    for action in actions:
        # action, _ = agent1.sample(state)
        state, reward, done, _ = env.step(action)
        done_count += 1
        total_reward += reward
        if done:
            break
    #   img.set_data(env.render(mode='rgb_array'))
    #   display.display(plt.gcf())
    #   display.clear_output(wait=True)
    print(f"Your reward is : %.2f"%total_reward)
    test_total_reward.append(total_reward)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/__init__.py:422: UserWarning: torch.set_deterministic is deprecated and will be removed in a future release. Please use torch.use_deterministic_algorithms instead
#   "torch.set_deterministic is deprecated and will be removed in a future "
# Your reward is : 259.84
# Your reward is : 294.12
# Your reward is : 286.20
# Your reward is : 255.80
# Your reward is : 301.46

# %% [markdown]
# # 你的成績

# %%
print(f"Your final reward is : %.2f"%np.mean(test_total_reward))
# Out:
# Your final reward is : 279.49

# %% [markdown]
# ## 參考資料
#
# 以下是一些有用的參考資料。
# 建議同學們實做前，可以先參考第一則連結的上課影片。
# 在影片的最後有提到兩個有用的 Tips，這對於本次作業的實做非常有幫助。
#
# - [DRL Lecture 1: Policy Gradient (Review)](https://youtu.be/z95ZYgPgXOY)
# - [ML Lecture 23-3: Reinforcement Learning (including Q-learning) start at 30:00](https://youtu.be/2-JNBzCq77c?t=1800)
# - [Lecture 7: Policy Gradient, David Silver](http://www0.cs.ucl.ac.uk/staff/d.silver/web/Teaching_files/pg.pdf)
